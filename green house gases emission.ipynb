# %% [markdown]
# # BUSINESS PROBLEM:
# Analyzing the comparision between India and China by considering their Green house gases over a time period of 26 years i.e from 1990 to 2016

# %%
#Importing the required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # loading the data file

# %%
#Loading the data file
data=pd.read_excel("/Users\SAHITHI\Downloads\green house gas emission\CW_CAIT_GHG_Emissions (1).xlsx")

# %%
#Glimpse of the data
data.head()
# Out:
#   Country Source                 Sector      Gas     1990     1991     1992  \
# 0     AFG   CAIT   Total excluding LUCF  All GHG  15.1377  15.0550  13.5994
# 1     AFG   CAIT   Total including LUCF  All GHG  15.1377  15.0550  13.5994
# 2     AFG   CAIT                Energy   All GHG   5.7703   5.2736   3.7116
# 3     AFG   CAIT  Industrial Processes   All GHG   0.0519   0.0545   0.0601
# 4     AFG   CAIT           Agriculture   All GHG   8.0869   8.4105   8.4235
#
#       1993     1994     1995  ...     2007     2008     2009     2010  \
# 0  13.4311  13.2379  13.4476  ...  24.7830  31.3933  37.7192  44.7496
# 1  13.4311  13.2379  13.4476  ...  24.7830  31.3933  37.7192  44.7496
# 2   3.3758   3.0547   2.7409  ...   9.9026  15.0853  20.9019  25.8391
# 3   0.0627   0.0653   0.0680  ...   0.1768   0.2027   0.2230   0.2489
# 4   8.5005   8.5380   8.9711  ...  12.1242  13.4483  13.8596  15.8493
#
#       2011     2012     2013     2014     2015     2016
# ...

# %% [markdown]
# checking the tuple

# %%
#Checking the tuples
data.shape
# Out:
# (8495, 31)

# %% [markdown]
# # Techincal summary of the data

# %%
#Technical Summary of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8495 entries, 0 to 8494
# Data columns (total 31 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  8495 non-null   object
#  1   Source   8495 non-null   object
#  2   Sector   8495 non-null   object
#  3   Gas      8495 non-null   object
#  4   1990     8351 non-null   float64
#  5   1991     8398 non-null   float64
#  6   1992     8428 non-null   float64
#  7   1993     8430 non-null   float64
#  8   1994     8431 non-null   float64
#  9   1995     8442 non-null   float64
#  10  1996     8444 non-null   float64
#  11  1997     8444 non-null   float64
#  12  1998     8444 non-null   float64
#  13  1999     8444 non-null   float64
#  14  2000     8466 non-null   float64
#  15  2001     8464 non-null   float64
#  16  2002     8464 non-null   float64
#  17  2003     8465 non-null   float64
#  18  2004     8465 non-null   float64
#  19  2005     8476 non-null   float64
# ...

# %% [markdown]
# checking the columns

# %%
#Checking the columns
data.columns
# Out:
# Index(['Country',  'Source',  'Sector',     'Gas',      1990,      1991,
#             1992,      1993,      1994,      1995,      1996,      1997,
#             1998,      1999,      2000,      2001,      2002,      2003,
#             2004,      2005,      2006,      2007,      2008,      2009,
#             2010,      2011,      2012,      2013,      2014,      2015,
#             2016],
#       dtype='object')

# %% [markdown]
# # Dropping unnecessary column

# %%
#Dropping unnecessary column
data.drop(columns="Source",inplace=True)

# %% [markdown]
# # data.head()

# %% [markdown]
# # HANDLING A MISSING VALUES

# %%
#Checking for the missing values
data["Country"].isnull().sum()
# Out:
# 0

# %% [markdown]
# splitting data of india and china

# %%
data_ind=data[data['Country']=='IND']
data_ind.drop('Country',axis=1,inplace=True)
data_chn=data[data['Country']=='CHN']
data_chn.drop('Country',axis=1,inplace=True)
# Out:
# C:\Users\SAHITHI\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data_ind.head()
# Out:
#                      Sector      Gas       1990       1991       1992  \
# 3442   Total excluding LUCF  All GHG  1225.5293  1280.5356  1312.2574
# 3443   Total including LUCF  All GHG  1183.0548  1238.0610  1269.7829
# 3444                Energy   All GHG   607.9098   652.3272   675.8356
# 3445  Industrial Processes   All GHG    26.4454    28.9959    30.0564
# 3446           Agriculture   All GHG   566.6385   574.0205   580.5171
#
#            1993       1994       1995       1996       1997  ...       2007  \
# 3442  1343.7544  1389.9651  1456.4617  1507.5138  1564.4585  ...  2200.5348
# 3443  1301.2799  1347.4906  1413.9872  1459.0376  1515.7486  ...  2078.8153
# 3444   698.1258   733.2908   786.1552   819.8767   861.2829  ...  1368.9580
# 3445    31.8969    34.2874    37.7537    41.9388    46.3638  ...    81.1489
# 3446   587.2270   595.2260   599.6481   607.0502   612.4201  ...   679.9023
#
#            2008       2009       2010       2011       2012       2013  \
# ...

# %%
data_chn.head()
# Out:
#                      Sector      Gas       1990       1991       1992  \
# 1392   Total excluding LUCF  All GHG  3220.1898  3369.7290  3501.0730
# 1393   Total including LUCF  All GHG  2901.7832  3051.3225  3182.6664
# 1394                Energy   All GHG  2342.7083  2459.0971  2558.3859
# 1395  Industrial Processes   All GHG    94.3451   112.5954   135.1558
# 1396           Agriculture   All GHG   588.4295   598.5780   603.3212
#
#            1993       1994       1995       1996       1997  ...       2007  \
# 1392  3724.1333  3875.1246  4264.6096  4300.7567  4309.8429  ...  8494.9031
# 1393  3405.7267  3556.7180  3946.2031  3980.4772  3989.4505  ...  8102.4560
# 1394  2767.6748  2870.8636  3185.3493  3170.9645  3238.5797  ...  6981.6668
# 1395   157.0162   180.0765   204.1116   219.9035   237.3954  ...   698.1586
# 1396   590.4807   610.4713   669.6024   712.5130   644.6629  ...   680.7117
#
#            2008       2009        2010        2011        2012        2013  \
# ...

# %% [markdown]
# # excluding 2 columns of the data(india)

# %%
#Excluding 2 columns of the data(India)
data_ind=data_ind[data_ind['Sector']!='Total excluding LUCF']
data_ind=data_ind[data_ind['Sector']!='Total including LUCF']

# %% [markdown]
# # excluding 2 columns of the data (china)

# %%
#Excluding 2 columns of the data(China)
data_chn=data_chn[data_chn['Sector']!='Total excluding LUCF']
data_chn=data_chn[data_chn['Sector']!='Total including LUCF']

# %%
#Slicing of the data(India)
data_ind_ghg=data_ind.iloc[0:12]

# %%
#Dropping Gas Column
data_ind_ghg.drop('Gas',axis=1,inplace=True)
# Out:
# C:\Users\SAHITHI\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#Slicing of the data(China)
data_chn_ghg=data_chn.iloc[0:12]

# %%
#Dropping Gas Column
data_chn_ghg.drop('Gas',axis=1,inplace=True)

# %%
#Reading the years into a variable
years=[i for i in range(1990,2017)]

# %%
#Knowing the different types of sectors present
data["Sector"].unique()
# Out:
# array(['Total excluding LUCF', 'Total including LUCF', 'Energy ',
#        'Industrial Processes ', 'Agriculture ', 'Waste ',
#        'Land-Use Change and Forestry ', 'Other Fuel Combustion ',
#        'Fugitive Emissions ', 'Bunker Fuels ', 'Electricity/Heat ',
#        'Manufacturing/Construction ', 'Transportation ', 'Building'],
#       dtype=object)

# %%
#Passing the values into respective lists
chn_values=[]
ind_values=[]
for i in range(0,11):
  v=data_ind_ghg.iloc[i,1:]
  ind_values.append(list(v))
  v=data_chn_ghg.iloc[i,1:]
  chn_values.append(list(v))

# %%
#Reading the list values of China
chn_values
# Out:
# [[2342.7083,
#   2459.0971,
#   2558.3859,
#   2767.6748,
#   2870.8636,
#   3185.3493,
#   3170.9645,
#   3238.5797,
#   3347.4948,
#   3261.61,
#   3454.3252,
#   3624.5982,
#   3894.2711,
#   4464.6441,
#   5152.317,
#   5830.99,
#   6427.8784,
#   6981.6668,
#   7220.5551,
#   7724.8435,
#   8431.0319,
#   9247.435,
#   9537.9381,
#   9937.4792,
#   9895.2202,
#   9896.1613,
#   9848.1222],
#  [94.3451,
#   112.5954,
#   135.1558,
#   157.0162,
#   180.0765,
#   204.1116,
#   219.9035,
#   237.3954,
#   253.3873,
#   277.7792,
#   301.3711,
#   344.6323,
#   387.2935,
#   452.7547,
#   504.4159,
#   552.8771,
#   632.3179,
#   698.1586,
#   729.9994,
#   808.6401,
#   885.5808,
#   975.3575,
#   1002.3342,
#   1058.9834,
#   1112.4326,
#   1090.6818,
#   1122.484],
#  [588.4295,
#   598.578,
#   603.3212,
#   590.4807,
#   610.4713,
#   669.6024,
#   712.513,
#   644.6629,
#   667.1362,
#   687.2893,
#   675.7694,
#   664.5485,
#   671.4378,
#   660.5166,
#   679.288,
# ...

# %%
#Reading the list values of India
ind_values
# Out:
# [[607.9098,
#   652.3272,
#   675.8356,
#   698.1258,
#   733.2908,
#   786.1552,
#   819.8767,
#   861.2829,
#   876.9797,
#   939.4312,
#   975.3827,
#   990.4207,
#   1024.2676,
#   1047.2539,
#   1124.8631,
#   1178.5552,
#   1252.9699,
#   1368.958,
#   1449.6462,
#   1615.9532,
#   1701.3867,
#   1784.9095,
#   1920.3606,
#   1970.1098,
#   2132.6874,
#   2142.7196,
#   2193.4893],
#  [26.4454,
#   28.9959,
#   30.0564,
#   31.8969,
#   34.2874,
#   37.7537,
#   41.9388,
#   46.3638,
#   49.8788,
#   55.6038,
#   57.4889,
#   59.2145,
#   63.0902,
#   66.0958,
#   68.6115,
#   72.5371,
#   76.398,
#   81.1489,
#   86.1898,
#   98.6307,
#   105.4216,
#   111.4093,
#   117.187,
#   120.9546,
#   125.5223,
#   130.19,
#   130.6061],
#  [566.6385,
#   574.0205,
#   580.5171,
#   587.227,
#   595.226,
#   599.6481,
#   607.0502,
#   612.4201,
#   619.6771,
#   623.2778,
#   617.94,
#   623.077,
#   607.1008,
#   618.8652,
#   628.604,
#   647.852,
#   662.5844,
#   679.9023,
# ...

# %%
plt.subplot(11,1,1)
plt.plot(years,chn_values[0],label='China')
plt.plot(years,ind_values[0],label='India')
plt.legend()
plt.title('China vs India Emission from Energy')

plt.subplot(11,1,2)
plt.plot(years,chn_values[1],label='China')
plt.plot(years,ind_values[1],label='India')
plt.legend()
plt.title('China vs India Emission from Industrial Processes')

plt.subplot(11,1,3)
plt.plot(years,chn_values[2],label='China')
plt.plot(years,ind_values[2],label='India')
plt.legend()
plt.title('China vs India Emission from Agriculture')

plt.subplot(11,1,4)
plt.plot(years,chn_values[3],label='China')
plt.plot(years,ind_values[3],label='India')
plt.legend()
plt.title('China vs India Emission from Waste')


plt.subplot(11,1,5)
plt.plot(years,chn_values[4],label='China')
plt.plot(years,ind_values[4],label='India')
plt.legend()
plt.title('China vs India Emission from Land-Use Change and Forestry')

plt.subplot(11,1,6)
plt.plot(years,chn_values[5],label='China')
plt.plot(years,ind_values[5],label='India')
plt.legend()
plt.title('China vs India from Bunker Fuels')

plt.subplot(11,1,7)
plt.plot(years,chn_values[6],label='China')
plt.plot(years,ind_values[6],label='India')
plt.legend()
plt.title('China vs India from Electricity/Heat')

plt.subplot(11,1,8)
plt.plot(years,chn_values[7],label='China')
plt.plot(years,ind_values[7],label='India')
plt.legend()
plt.title('China vs India from Manufacturing/Construction')

plt.subplot(11,1,9)
plt.plot(years,chn_values[8],label='China')
plt.plot(years,ind_values[8],label='India')
plt.legend()
plt.title('China vs India fromTransportation')

plt.subplot(11,1,10)
plt.plot(years,chn_values[9],label='China')
plt.plot(years,ind_values[9],label='India')
plt.legend()
plt.title('China vs India from Building')

plt.subplot(11,1,11)
plt.plot(years,chn_values[10],label='China')
plt.plot(years,ind_values[10],label='India')
plt.legend()
plt.title('China vs India from Other Fuel Combustion')
plt.subplots_adjust(top=11,hspace=0.4)

# %%
data["Gas"].unique()
# Out:
# array(['All GHG', 'CO2', 'CH4', 'N2O', 'F-Gas'], dtype=object)

# %% [markdown]
# # Grouped by Gas, India Vs China

# %%
sectors=list(data_ind['Sector'])

# %%
l=[]
plt.subplot(211)
for i in range(0,10):
  v=data_ind.groupby('Gas').get_group('CO2').iloc[i,2:]
  l.append(list(v))
for i in range(0,10):
  plt.plot(years,l[i],label=sectors[i])
plt.title('India vs China CO2 emissions')
l=[]
plt.subplot(212)
for i in range(0,10):
  v=data_chn.groupby('Gas').get_group('CO2').iloc[i,2:]
  l.append(list(v))
for i in range(0,10):
  plt.plot(years,l[i],label=sectors[i])
plt.legend(bbox_to_anchor=(1.04,1), loc="lower left")

# %%
l=[]
plt.subplot(211)
for i in range(0,7):
  v=data_ind.groupby('Gas').get_group('CH4').iloc[i,2:]
  l.append(list(v))
for i in range(0,7):
  plt.plot(years,l[i],label=sectors[i])
plt.title('India vs China CH4 emissions')
l=[]
plt.subplot(212)
for i in range(0,7):
  v=data_chn.groupby('Gas').get_group('CO2').iloc[i,2:]
  l.append(list(v))
for i in range(0,7):
  plt.plot(years,l[i],label=sectors[i])
plt.legend(bbox_to_anchor=(1.04,1), loc="lower left")

# %%
l=[]
plt.subplot(211)
for i in range(0,7):
  v=data_ind.groupby('Gas').get_group('N2O').iloc[i,2:]
  l.append(list(v))
for i in range(0,7):
  plt.plot(years,l[i],label=sectors[i])
plt.title('India vs China N2O emissions')
l=[]
plt.subplot(212)
for i in range(0,7):
  v=data_chn.groupby('Gas').get_group('N2O').iloc[i,2:]
  l.append(list(v))
for i in range(0,7):
  plt.plot(years,l[i],label=sectors[i])
plt.legend(bbox_to_anchor=(1.04,1), loc="lower left")

# %%
l=[]
plt.subplot(211)
for i in range(0,1):
  v=data_ind.groupby('Gas').get_group('F-Gas').iloc[i,2:]
  l.append(list(v))
for i in range(0,1):
  plt.plot(years,l[i],label='Industrial Processes')
plt.title('India vs China F-Gas emissions')
l=[]
plt.subplot(212)
for i in range(0,1):
  v=data_chn.groupby('Gas').get_group('F-Gas').iloc[i,2:]
  l.append(list(v))
for i in range(0,1):
  plt.plot(years,l[i],label='Industrial Processes')
plt.legend(bbox_to_anchor=(1.04,1), loc="lower left")

# %% [markdown]
# # Sector Wise

# %% [markdown]
# The graph is clearly depicting that the emissions from ENERGY of China is much higher when compared to India.
#
# India has the standability but whereas China has a sudden gradual increase between 1995-2000.
#
# They have massive populations topping 1.3 billion, and both are heavy users of coal, the worst fossil fuel in terms of energy emissions. China alone consumed more than half of the world’s coal in 2019, according to the International Energy Agency. India is currently a distant No. 2 with 11% of the global share, but its share is expected to rise to around 14% by 2030
#
# The Energy Sector Produces the Most Greenhouse Gas Emissions Energy consumption is by far the biggest source of human-caused greenhouse gas emissions.
#
# Activities driving most energy emissions include road transportation (12.5% of total emissions),buildings (11.4% of total emissions) Emissions from those activities include both direct emissions from fossil fuel combustion, as well as indirect emissions from activities such as use of electricity.
#
# The “other industry” category contains all activities that do not squarely fall within the other categories. As such, it covers a wide range of activities, including non-metallic metals, construction, mining and quarrying, textile and leather, wood and wood products, transportation equipment and more.
#
# In comparison, emissions from the largest-emitting subsector within the energy sector, electricity and heat generation, increased 78% from 1990 to 2013, but then dropped by 2.4% between 2013 and 2016. The decrease was driven by various factors, including a shift to natural gas from coal and increased use of renewables.
#
# However, the latest carbon emissions data suggests that emissions from this energy subsector rose again in 2017 and 2018 by 1.3% and 2% respectively, while maintaining a marginal increase of 0.06% in 2019.
#
# A small number of countries contribute most of the greenhouse gas emissions, with the top 10 emitters accounting for over two-thirds of annual global greenhouse gas emissions. Most of them also have large populations and economies, together accounting for over 50% of the global population and 75% of the world’s GDP.
#
# China is the biggest emitter at 26.1% of global greenhouse gas emissions, followed by the United States at 12.67%, the European Union at 7.52% and India at 7.08%.
#
# Among the top 10 total greenhouse gas emitters, Canada and the United States have the highest per capita greenhouse gas emissions at 20.6 tCO2e per person and 17.74 tCO2e per person, respectively, while India has the lowest at 2.47 tCO2e per person.
#
# China’s per capita emissions (8.4 tCO2e) continue to rise, surpassing those of the European Union (7.46 tCO2e).

# %% [markdown]
# # Ways to Overcome

# %% [markdown]
# The largest emissions sources, like the energy sector, are good places to start climate ambition programmes
#
# The State of Climate Action states/reveals that in order for the world to get on track for the emission cuts required by 2030, we need to phase out coal in electricity generation five times faster, accelerate the increase in annual tree cover gain five times faster and accelerate the increase in share of low-carbon fuels by eight times faster, among other actions
#
# Switching to
#
# 1.Renewable energy,
#
# 2.Electrifying the transportation sector,
#
# 3.Introducing more sustainable agriculture practices,
#
# 4.Curbing deforestation and forest degradation and
#
# 5.Producing less waste
#
# are a few critical steps to drive greenhouse gas emissions downward and set the world on course for a safer future.

# %% [markdown]
# # Gas Wise

# %% [markdown]
# Globally, greenhouse gas emissions have grown by 50% from 1990 to 2016.
#
# In 2014, the top carbon dioxide (CO2) emitters were China, the United States, the European Union, India, the Russian Federation, and Japan. These data include CO2 emissions from fossil fuel combustion, as well as cement manufacturing and gas flaring.
#
# Agriculture, deforestation, and other land-use changes have been the second-largest contributors
#
# Most CO2 emissions (93%) are from the use of fossil fuels, especially for generation of electricity and heat, transportation and manufacturing and consumption. Land use, land-use change and forestry is another contributor (3.3%) to human-made CO2 emissions, mostly due to deforestation.
#
# Methane (CH4) and nitrous oxide (N2O) make up 17.2% and 6.3% of total greenhouse gas emissions, respectively, mostly from agriculture, waste treatment.

# %% [markdown]
# # Ways to Overcome

# %% [markdown]
# Should stop:
#
# 1.Land clearing for agriculture, and
#
# 2.Degradation of soils
#
# 3.Likewise,land can also remove CO2 from the atmosphere through
#
# 4.Reforestation,
#
# 5.Improvement of soils, and other activities.
#
# Reducing Agricultural activities, waste management, energy use, and biomass burning all contribute to the reduction of CH4 emissions
#
# Agricultural activities, such as fertilizer(which are the primary source of N2O emissions)must be prevented and substituted by organics.Reducing Fossil fuel combustion reduces generation of N2O.
#
# Reducing the usage of Industrial processes, refrigeration, and the use of a variety of consumer products help to stop the contribution to emissions of F-gases
